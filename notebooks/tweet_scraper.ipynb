# %% [markdown]
# This is a tweet scaping script based *Heavily* on the example script found here: https://gist.github.com/bjmarsh/315a632aa1ab0e8436e631f8a1acf40b orignially created by Bennett Marsh.

# %%
from collections import defaultdict
import os, sys
import time
import pandas as pd
import GetOldTweets3 as got

# %%
os.makedirs('tweet_data', exist_ok=True)
users = ["elonmusk"]
username = users[0]

# %%
count = 10
# Creation of query object                                                                                                                                                                                      
tweetCriteria = got.manager.TweetCriteria().setUsername(username)\
                                               .setMaxTweets(count)\
                                               .setSince("2020-05-30")\
                                               .setUntil("2020-05-31")
tweets = None
for ntries in range(2):        
    try:
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    except SystemExit:
        print("Trying again in 15 minutes.")
        time.sleep(15*60)
    else:
        break
if tweets is None:
    print("Failed after 2 tries, quitting!")
    exit(1)

# %%
len(tweets)
# Out:
# 4

# %%
tweets[0]

# %% [markdown]
# Got it, the getTweets() function returns a tweet object.  No docstring on the got tweet object though.

# %%
tweets[0].id
tweets[0].to

# %% [markdown]
# Bennet's original script does just fine in gathering up all of Elon's tweets.  I'd like to have a record of the semantic content of the tweet/reply conversations that Elon has with his followers and twitters API does not make this properly available.  I'm going to have to fudge it, but I think that this algorithm will do a decent job of getting at least some of the conversations Elon has.

# %%
def get_other_user_reply(username,t_init,t_final): 
    #searches a secondary user's tweets within a range of time and 
    #returns tweets that either reply to or @elonmusk
    print(username)
    count = 0
    # Creation of query object                                                                                                                                                                                      
    tweetCriteria = got.manager.TweetCriteria().setUsername(username)\
                                               .setMaxTweets(count)\
                                               .setSince(t_init)\
                                               .setUntil(t_final)
    # Creation of list that contains all tweets                                                                                                                                                                     
    tweets = None
    for ntries in range(5):
        try:
            tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        except SystemExit:
            print("Trying again in 15 minutes.")
            time.sleep(15*60)
        else:
            break
    if tweets is None:
        print("Failed after 5 tries, quitting!")
        exit(1)

    data = defaultdict(list)
    for t in tweets:
        if t.to == 'elonmusk' or t.mentions == '@elonmusk':
            data["username"].append(username)
            data["tweet_id"].append(t.id)
            data["reply_to"].append(t.to)
            data["date"].append(t.date)
            data["retweets"].append(t.retweets)
            data["favorites"].append(t.favorites)
            data["hashtags"].append(list(set(t.hashtags.split())))
            data["mentions"].append(t.mentions)
            data["text"].append(t.text)
            data["permalink"].append(t.permalink)
        else:
            pass
    return data

# %%
elon_tweets_df = pd.read_csv('./tweet_data/elonmusk.csv')

# %%
elon_tweets_df.columns
# Out:
# Index(['Unnamed: 0', 'username', 'tweet_id', 'reply_to', 'date', 'retweets',
#        'favorites', 'hashtags', 'mentions', 'text', 'permalink'],
#       dtype='object')

# %%
# Convert 'Time' column to datetime and strip time information.
elon_tweets_df['Time'] = pd.to_datetime(elon_tweets_df['date'])#.dt.date

# %%
elon_tweets_df.dtypes
# Out:
# Unnamed: 0                  int64
# username                   object
# tweet_id                    int64
# reply_to                   object
# date                       object
# retweets                    int64
# favorites                   int64
# hashtags                   object
# mentions                   object
# text                       object
# permalink                  object
# Time          datetime64[ns, UTC]
# dtype: object

# %%
elon_tweets_df = elon_tweets_df.drop(['Unnamed: 0','date'],axis='columns')

# %%
elon_tweets_df.index
# 5656                  ['#donotpanic']               NaN
# 5863      ['#ThrowFlamesResponsibly']               NaN
# 5927                     ['#Pravduh']               NaN
# 6562                 ['#FalconHeavy']               NaN
# 6563                 ['#FalconHeavy']               NaN
# 6564                 ['#FalconHeavy']               NaN
# 6565      ['#FalconHeavy', '#SpaceX']               NaN
# 9056                        ['#Yutu']               NaN
# 9169            ['#KatieWoodencloak']               NaN
# 9388                     ['#TeslaTX']               NaN
# 9389                      ['#hhgttg']               NaN
# 9431                        ['#SXSW']               NaN
# 9438                        ['#SXSW']               NaN
# 9442                      ['#Dragon']             @NASA
# 9482                        ['#SB47']            @49ers
# 9508               ['#Zeitgeist2012']               NaN
# 9520            ['#AwesomeXmasGifts']               NaN
# 9530                     ['#Climate']     @newscientist
# 9609                  ['#OccupyMars']            @n23mc
# 9631                      ['#Dragon']               NaN
# 9632                      ['#Dragon']               NaN
# 9633                      ['#Dragon']               NaN
# 9634                      ['#Dragon']               NaN
# 9636          ['#GrasshopperProject']               NaN
# 9638                      ['#Dragon']               NaN
# 9640                ['#dragonlaunch']               NaN
# 9641                ['#dragonlaunch']               NaN
# 9642                ['#DragonLaunch']               NaN
# 9643                ['#DragonLaunch']               NaN
# 9647                ['#DragonLaunch']               NaN
# 9648                ['#dragonlaunch']               NaN
# 9663                 ['#APSpaceChat']    @love_to_dream
# 9664  ['#OccupyMars', '#APSpaceChat']       @Weaverwerx
# 9665                 ['#APSpaceChat']          @WHester
# 9693                  ['#antarctica']  @Polar_Broadband
# 9707                  ['#PlutoStamp']             @NASA
# 9766    ['#whatcouldpossiblygowrong']               NaN
#
#                                                    text  \
# 561                                  #CancelNewsNetwork
# 1144                          #DeleteFacebook It’s lame
# 2045  Excited about launching @NASA asteroid defense...
# 2988  Actually, I stole it from my secret meme deale...
# 4294                                     #NewProfilePic
# 5084                                        #OccupyMars
# 5656                                        #donotpanic
# 5863  Terms & conditions for “Not-a-Flamethrower” Pl...
# 5927                                           #Pravduh
# 6562  Camera views from inside the payload fairing #...
# 6563  Launch auto-sequence initiated (aka the holy m...
# 6564  Upper atmosphere winds currently 20% above max...
# 6565                Flight profile #FalconHeavy #SpaceX
# 9056                    Welcome back Jade Rabbit! #Yutu
# 9169  One of the first Tesla Supercharger stations i...
# 9388  Am headed to TX next week to thank people pers...
# 9389  Certainly true that many people believe that T...
# 9431  Will show Johnny Cash hover slam rocket video ...
# 9438  Arrived Austin. Talking with TX House about cr...
# 9442  Just received #Dragon docking clearance from @...
# 9482  Great spirit here in the Superdome. Awesome ra...
# 9508  Cool video recap of the big events of the year...
# 9520  Uranium ore now available on Amazon! So much m...
# 9530  On the plus side...“@newscientist: #Climate ch...
# 9609  @n23mc I think we will see people on Mars in l...
# 9631  Splashdown successful!! Sending fast boat to D...
# 9632  Thrusters will also fire during reentry to adj...
# 9633  Spaceship has departed from the International ...
# 9634  Space Station tracking spaceship docking appro...
# 9636  Dragon flies over the SpaceX #GrasshopperProje...
# 9638  About 110 miles away and the spacecraft is now...
# 9640  Dragon fly by of Space Station planned for 12:...
# 9641  Launch video of Falcon 9 from Cape Canaveral t...
# 9642  Navigation bay pointing to deep space and star...
# 6563 2018-02-06 18:52:08+00:00
# 6564 2018-02-06 17:02:41+00:00
# 6565 2018-02-06 16:38:31+00:00
# 9056 2014-02-14 00:58:23+00:00
# 9169 2013-07-28 02:47:17+00:00
# 9388 2013-04-02 17:49:11+00:00
# 9389 2013-04-02 16:19:41+00:00
# 9431 2013-03-09 19:55:35+00:00
# 9438 2013-03-08 14:37:27+00:00
# 9442 2013-03-02 20:58:29+00:00
# 9482 2013-02-04 03:06:02+00:00
# 9508 2012-12-12 20:06:11+00:00
# 9520 2012-12-02 21:12:03+00:00
# 9530 2012-11-22 16:32:13+00:00
# 9609 2012-07-12 14:57:32+00:00
# 9631 2012-05-31 15:48:16+00:00
# 9632 2012-05-31 14:31:25+00:00
# 9633 2012-05-31 14:21:33+00:00
# 9634 2012-05-25 20:23:00+00:00
# 9636 2012-05-24 18:15:19+00:00
# 9638 2012-05-24 06:23:53+00:00
# 9640 2012-05-23 15:09:40+00:00
# 9641 2012-05-22 12:27:20+00:00
# 9642 2012-05-22 10:38:25+00:00
# 9643 2012-05-22 10:31:20+00:00
# 9647 2012-05-22 07:43:41+00:00
# 9648 2012-05-22 07:34:32+00:00
# 9663 2012-05-03 18:27:19+00:00
# 9664 2012-05-03 18:22:41+00:00
# 9665 2012-05-03 18:15:01+00:00
# 9693 2012-03-20 21:05:26+00:00
# 9707 2012-02-25 18:36:12+00:00
# 9766 2011-12-31 13:06:23+00:00

# %%
from datetime import datetime

# %%
datetime.utcnow()
# Out:
# datetime.datetime(2020, 6, 2, 2, 40, 26, 537553)

# %%
t = elon_tweets_df['Time'].iloc[0]
elon_tweets_df['Time'].iloc[0]
# Out:
# Timestamp('2020-05-31 19:46:25+0000', tz='UTC')

# %%
t.date().day
# Out:
# 31

# %%
from collections import defaultdict
import os, sys
import time
import pandas as pd
import GetOldTweets3 as got

def get_new_tweets(t_last_tweet,username = "elonmusk"):
    """Function to scrape the recent tweets of Elon Musk"""
    #t_last_tweet must be pandas Timestamp data
    os.makedirs('tweet_data', exist_ok=True)
    date_str = str(t_last_tweet.date().year)+"-"\
              +str(t_last_tweet.date().month)+"-"\
              +str(t_last_tweet.date().day)
    count = 0
    # Creation of query object                                                                                                                                                                                      
    tweetCriteria = got.manager.TweetCriteria().setUsername(username)\
                                               .setMaxTweets(count)\
                                               .setSince(date_str)
    # Creation of list that contains all tweets                                                                                                                                                                     
    tweets = None
    for ntries in range(5):
        try:
            tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        except SystemExit:
            print("Trying again in 15 minutes.")
            time.sleep(15*60)
        else:
            break
    if tweets is None:
        print("Failed after 5 tries, quitting!")
        exit(1)

    data = defaultdict(list)
    for t in tweets:
        data["username"].append(username)
        data["tweet_id"].append(t.id)
        data["reply_to"].append(t.to)
        data["date"].append(t.date)
        data["retweets"].append(t.retweets)
        data["favorites"].append(t.favorites)
        data["hashtags"].append(list(set(t.hashtags.split())))
        data["mentions"].append(t.mentions)
        data["text"].append(t.text)
        data["permalink"].append(t.permalink)
    if len(data) == 0: #no new tweets
        return None
    else:
        #make a DataFrame out of the scraped tweets
        df = pd.DataFrame(data, columns=["username","tweet_id","reply_to","date","retweets","favorites","hashtags","mentions","text","permalink"])        
        # Convert 'Time' column to datetime and strip time information.
        df['Time'] = pd.to_datetime(df['date'])
        #df = df.drop(['Unnamed: 0','date'],axis='columns') #unused columns
        return df

# %%
test_df = get_new_tweets(elon_tweets_df['Time'].iloc[0],username = "elonmusk")

# %%
test_df.head()
# Out:
#    username             tweet_id      reply_to                      date  \
# 0  elonmusk  1267650659320500226          None 2020-06-02 02:54:03+00:00
# 1  elonmusk  1267531196751323144      PPathole 2020-06-01 18:59:21+00:00
# 2  elonmusk  1267415489111785472  mharrisonair 2020-06-01 11:19:34+00:00
# 3  elonmusk  1267409179339296768      DjKeyWay 2020-06-01 10:54:30+00:00
# 4  elonmusk  1267402337653587968  scale_banana 2020-06-01 10:27:19+00:00
#
#    retweets  favorites             hashtags mentions  \
# 0      3430      42194                   []
# 1      1779      26679                   []
# 2       410      10044                   []
# 3       774       4926  [#JusticeForGeorge]
# 4      1474      61511                   []
#
#                                                 text  \
# 0                            Off Twitter for a while
# 1  Starship is the key to making life multiplanet...
# 2                                          Well said
# 3  Definitely not right that the other officers w...
# 4                               Where’s the banana!?
#
#                                            permalink                      Time
# 0  https://twitter.com/elonmusk/status/1267650659... 2020-06-02 02:54:03+00:00
# 1  https://twitter.com/elonmusk/status/1267531196... 2020-06-01 18:59:21+00:00
# 2  https://twitter.com/elonmusk/status/1267415489... 2020-06-01 11:19:34+00:00
# 3  https://twitter.com/elonmusk/status/1267409179... 2020-06-01 10:54:30+00:00
# 4  https://twitter.com/elonmusk/status/1267402337... 2020-06-01 10:27:19+00:00

# %%
elon_tweets_df.to_csv(f"tweet_data/elonmusk.csv")

# %%
#not we'll have to do a .drop and set the 'Time' column to the proper values every time
reload_test_df = pd.read_csv('./tweet_data/elonmusk.csv').drop(['Unnamed: 0'],axis='columns')
reload_test_df['Time'] = pd.to_datetime(reload_test_df['Time'])

# %%
reload_test_df.head()
# Out:
#    Unnamed: 0  username             tweet_id         reply_to  retweets  \
# 0           0  elonmusk  1267180654896254976           SpaceX     22581
# 1           1  elonmusk  1267160409498357764  NASASpaceflight        81
# 2           2  elonmusk  1267157474886455296  NASASpaceflight       708
# 3           3  elonmusk  1267156817295085575          Rogozin      1209
# 4           4  elonmusk  1267146619562201090           SpaceX      5576
#
#    favorites hashtags        mentions  \
# 0     250519       []             NaN
# 1       2494       []             NaN
# 2      14436       []             NaN
# 3       7558       []             NaN
# 4      67423       []  @Space_Station
#
#                                                 text  \
# 0                                   Nine years later
# 1                 Must be due to relativistic aging
# 2  Brought home by same person who placed it ther...
# 3  Спасибо, сэр, ха-ха. Мы рассчитываем на взаимо...
# 4  Congratulations Bob & Doug on docking & hatch ...
#
#                                            permalink  \
# 0  https://twitter.com/elonmusk/status/1267180654...
# 1  https://twitter.com/elonmusk/status/1267160409...
# 2  https://twitter.com/elonmusk/status/1267157474...
# 3  https://twitter.com/elonmusk/status/1267156817...
# 4  https://twitter.com/elonmusk/status/1267146619...
#
#                         Time
# 0  2020-05-31 19:46:25+00:00
# 1  2020-05-31 18:25:58+00:00
# 2  2020-05-31 18:14:19+00:00
# 3  2020-05-31 18:11:42+00:00
# 4  2020-05-31 17:31:11+00:00
